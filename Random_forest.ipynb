# %%
import pandas as pd

df= pd.read_excel('glass.xlsx',sheet_name=1)
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
### Dataset Structure
df.shape
# Out:
# (214, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %% [markdown]
# Dataset contains numeric features only
# Target column is usually named Type
# No categorical variables
# Small dataset → models may overfit

# %%
###missing values
df.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
###outlier detection
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %% [raw]
# Features like Ba, Fe, Mg show extreme values
# Tree-based models are robust to outliers → no removal needed

# %% [markdown]
# ### 2.DATA VISUALIZATION

# %%
import matplotlib.pyplot as plt

df.hist(figsize=(15,10))
plt.show()

# %%
### boxplot

plt.figure(figsize=(15,6))
df.boxplot()
plt.xticks(rotation=45)
plt.show()

# %%
### Correlation Heatmap
import seaborn as sns

plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %% [raw]
# RI correlated with Na & Ca
# K and Ba have low correlation with other features
# No multicollinearity issues for Random Forest

# %% [markdown]
# ### DATA PREPROCESSING

# %%
### Separate Features & Target
x = df.drop("Type", axis=1)
y = df["Type"]

# %% [raw]
# ### Encoding Categorical Variables
# Not required — dataset contains only numerical values.

# %% [raw]
# Feature Scaling
# Random Forest does not require scaling, but we apply it for consistency.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %% [markdown]
# ### Random Forest Model Implementation

# %%
### train-test-split
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x_scaled,y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# %%
### Random Forest Classifie
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=100,
    class_weight="balanced",
    random_state=42
)

rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=42)

# %%
### Model Evaluation
from sklearn.metrics import accuracy_score, classification_report

y_pred = rf.predict(x_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7441860465116279
#               precision    recall  f1-score   support
#
#            1       0.69      0.79      0.73        14
#            2       0.77      0.67      0.71        15
#            3       0.50      0.33      0.40         3
#            5       0.75      1.00      0.86         3
#            6       0.67      1.00      0.80         2
#            7       1.00      0.83      0.91         6
#
#     accuracy                           0.74        43
#    macro avg       0.73      0.77      0.74        43
# weighted avg       0.75      0.74      0.74        43

# %% [markdown]
# ### Bagging and Boosting Methods

# %%
###Bagging Classifier
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

bagging = BaggingClassifier(
    estimator=DecisionTreeClassifier(),
    n_estimators=100,
    random_state=42
)

bagging.fit(x_train, y_train)
y_bag = bagging.predict(x_test)

print("Bagging Accuracy:", accuracy_score(y_test, y_bag))
print(classification_report(y_test, y_bag))
# Out:
# Bagging Accuracy: 0.7906976744186046
#               precision    recall  f1-score   support
#
#            1       0.79      0.79      0.79        14
#            2       0.85      0.73      0.79        15
#            3       0.67      0.67      0.67         3
#            5       0.67      0.67      0.67         3
#            6       0.67      1.00      0.80         2
#            7       0.86      1.00      0.92         6
#
#     accuracy                           0.79        43
#    macro avg       0.75      0.81      0.77        43
# weighted avg       0.79      0.79      0.79        43

# %% [markdown]
# ### Boosting (AdaBoost)

# %%
from sklearn.ensemble import AdaBoostClassifier

boost = AdaBoostClassifier(
    n_estimators=100,
    random_state=42
)

boost.fit(x_train, y_train)
y_boost = boost.predict(x_test)

print("Boosting Accuracy:", accuracy_score(y_test, y_boost))
print(classification_report(y_test, y_boost))
# Out:
# Boosting Accuracy: 0.3953488372093023
#               precision    recall  f1-score   support
#
#            1       0.67      0.14      0.24        14
#            2       0.36      0.60      0.45        15
#            3       0.00      0.00      0.00         3
#            5       0.00      0.00      0.00         3
#            6       0.67      1.00      0.80         2
#            7       0.67      0.67      0.67         6
#
#     accuracy                           0.40        43
#    macro avg       0.39      0.40      0.36        43
# weighted avg       0.47      0.40      0.36        43

# %% [raw]
# Bagging vs Boosting (Theory)
# Bagging
# Models trained independently
# Reduces variance
# Example: Random Forest
#
# Boosting
# Models trained sequentially
# Focuses on previous errors
# Reduces bias
# Example: AdaBoost
